# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
for pid in ['tani', 'Yu', 'Okubo']:
    data = pd.read_csv('result/' + pid + '_baseline_Day1.csv')
    plt.plot(data['right'])

# %%
for pid in ['tani', 'Yu', 'Okubo']:
    data = pd.read_csv('result/' + pid + '_baseline_Day1.csv')
    print(np.average(data['right']), np.median(data['right']))
# Out:
# 841.7851956451547 662.3292043613394
# 1268.9675739691045 1006.0828219925158
# 910.9823312682323 802.1944215177708

# %%
def test(x):
    return None if type(x) == str else x

# %%
testdf = pd.DataFrame({'test' : [test(x) for x in ['test', 1,2,3, 'test', 4,5]], 'test2' : [test(x) for x in [6,7,'test', 4,'re', 7, 're']]})

# %%
testdf
# Out:
#    test  test2
# 0   NaN    6.0
# 1   1.0    7.0
# 2   2.0    NaN
# 3   3.0    4.0
# 4   NaN    NaN
# 5   4.0    7.0
# 6   5.0    NaN

# %%
p = testdf.count() / len(testdf)

# %%
all(p < 0.7)
# Out:
# False

# %%
testlist = []
for x in ['test', 1,2,3, 'test', 4,5]:
    testlist.append(test(x))

# %%
testlist
# Out:
# [None, 1, 2, 3, None, 4, 5]
