# %%
import pandas as pd
import numpy as np
import csv
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
pid = 'P01'
condition_data = pd.read_csv('result/' + pid + '_continuous_training.csv', index_col=0)

# %%
p_info
# Out:
#       condition
# pid
# P01  continuous
# P02  continuous
# P03  continuous
# P04  continuous
# P05  continuous
# P06  continuous
# P07     control
# P08     control
# P09     control
# P10     control
# P11         NaN
# P12         NaN
# P13         NaN
# P14         NaN
# P15         NaN
# P16         NaN
# P17         NaN
# P18         NaN

# %%
p_info = pd.read_csv('participants_data.csv', index_col=0)
condition = p_info[p_info.pid == pid].condition
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ad257701381f> in <module>
#       1 p_info = pd.read_csv('participants_data.csv', index_col=0)
# ----> 2 condition = p_info[p_info.pid == pid].condition
#
# c:\users\okamotolab\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pid'

# %%
ERD_list = []
ERD_per_list = []
for day, block in itertools.product(['Day1', 'Day2', 'Day3'], range(5)):
    with open('result/' + pid + '_FB_ERSP_' + day + '_b' + str(block) + '.csv', 'r') as f:
        data = list(csv.reader(f, quoting=csv.QUOTE_NONNUMERIC))
    
    for FB in data:
        ERD_list.append(np.average(FB))
        ERD_per_list.append(sum(i < -10 for i in FB) / len(FB))
condition_data['ERSP'] = ERD_list
condition_data['Percent'] = ERD_per_list

# %%
ERSP = condition_data.groupby(['pid', 'condition', 'day', 'block', 'hand'], sort=False, as_index=False).mean()
plt.plot(ERSP[ERSP.hand == 'left']['ERSP'])

# %%
plt.plot(ERSP[ERSP.hand == 'right']['ERSP'])

# %%
fatigue = pd.read_csv('result/' + pid + '_fatigue.csv', index_col=0)

# %%
fatigue
# Out:
#    pid   condition   day  block  fatigue  concentrate  difficulty  prediction
# 0  P01  continuous  Day1      0        5            6           5          65
# 1  P01  continuous  Day1      1        6            2           6          51
# 2  P01  continuous  Day1      2        5            6           5          70
# 3  P01  continuous  Day1      3        4            5           3          75
# 4  P01  continuous  Day1      4        5            3           5          61
# 0  P01  continuous  Day2      0        3            4           5          75
# 1  P01  continuous  Day2      1        5            4           4          68
# 2  P01  continuous  Day2      2        5            3           5          60
# 3  P01  continuous  Day2      3        5            3           5          67
# 4  P01  continuous  Day2      4        4            5           3          70
# 0  P01  continuous  Day3      0        6            3           5          70
# 1  P01  continuous  Day3      1        5            3           4          71
# 2  P01  continuous  Day3      2        5            5           3          65
# 3  P01  continuous  Day3      3        5            3           5          65
# 4  P01  continuous  Day3      4        6            5           5          60

# %%
fatigue['Percent'] = condition_data.groupby(['pid', 'condition', 'day', 'block'], sort=False, as_index=False).mean().Percent
fatigue['ERSP'] = condition_data.groupby(['pid', 'condition', 'day', 'block'], sort=False, as_index=False).mean().ERSP

# %%
fatigue
# Out:
#    pid   condition   day  block  fatigue  concentrate  difficulty  prediction  \
# 0  P01  continuous  Day1      0        5            6           5          65
# 1  P01  continuous  Day1      1        6            2           6          51
# 2  P01  continuous  Day1      2        5            6           5          70
# 3  P01  continuous  Day1      3        4            5           3          75
# 4  P01  continuous  Day1      4        5            3           5          61
# 0  P01  continuous  Day2      0        3            4           5          75
# 1  P01  continuous  Day2      1        5            4           4          68
# 2  P01  continuous  Day2      2        5            3           5          60
# 3  P01  continuous  Day2      3        5            3           5          67
# 4  P01  continuous  Day2      4        4            5           3          70
# 0  P01  continuous  Day3      0        6            3           5          70
# 1  P01  continuous  Day3      1        5            3           4          71
# 2  P01  continuous  Day3      2        5            5           3          65
# 3  P01  continuous  Day3      3        5            3           5          65
# 4  P01  continuous  Day3      4        6            5           5          60
#
#     Percent       ERSP
# 0  0.733833 -35.650713
# 1  0.604299 -23.929689
# 2  0.788115 -44.376403
# 3  0.727053 -39.473715
# 4  0.637477 -15.497974
# 0  0.733833 -35.650713
# 1  0.604299 -23.929689
# 2  0.788115 -44.376403
# 3  0.727053 -39.473715
# 4  0.637477 -15.497974
# 0  0.733833 -35.650713
# 1  0.604299 -23.929689
# 2  0.788115 -44.376403
# 3  0.727053 -39.473715
# 4  0.637477 -15.497974

# %%
sns.regplot(x='prediction', y='ERSP', data=fatigue)

# %%
sns.regplot(x='prediction', y='Percent', data=fatigue)
