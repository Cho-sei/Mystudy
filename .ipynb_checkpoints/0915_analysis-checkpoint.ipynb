# %%
import mne
from mne.time_frequency.multitaper import psd_array_multitaper
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import sys

# %%
def eval_MItask(task, relax, ch, fmin, fmax):
    TaskRelax = []
    for epoch in [task, relax]:
        psdList = []
        for array in epoch.get_data()[:, epoch.ch_names.index(ch), :]:
            psd, freqs = psd_array_multitaper(array, epoch.info['sfreq'], fmin=fmin, fmax=fmax)
            psdList.append(psd)
        TaskRelax.append(np.median(psdList))
    return 100 * (TaskRelax[0] - TaskRelax[1]) / TaskRelax[1]

# %%
def sep_block(epoch, label, init):
    eventdf = pd.DataFrame(events, columns=['ind', 'step', 'id'])
    RestIndex = eventdf[eventdf.id == event_id['rest']].ind.values
    
    BlockList = []
    init = init
    for index in np.insert(RestIndex, len(RestIndex), eventdf[eventdf.id == event_id['training_finish']].ind.item()):
        BlockIndex = len(eventdf[(eventdf.id == event_id[label]) & (eventdf.ind < index)])
        BlockList.append(epoch[init:BlockIndex])
        init = BlockIndex
    
    return BlockList

# %%
def calc_block_psd(epochs, label, ch, init=0):
    epochList = sep_block(epochs, label, init)
    
    BlockPsdList = []
    for epoch in epochList:
        PsdList = []
        for array in epoch.get_data()[:, epoch.ch_names.index(ch), :]:
            psd, freqs = psd_array_multitaper(array, epoch.info['sfreq'], fmin=fmin, fmax=fmax)
            PsdList.append(psd)
        BlockPsdList.append(np.median(psd))

    return BlockPsdList

# %%
def create_MItest_erd_df(dfList, task, relax, label):
    for i in range(2): #left and right
        ch = 'C4' if i == 0 else 'C3'
        ERSP = eval_MItask(task[i], relax[i], ch, fmin, fmax)
        dfList[i] = dfList[i].append(pd.Series([label, ERSP], index=dfList[i].columns), ignore_index=True)

# %%
def create_block_erd_df(dfList, task, baseline):
    for i in range(2): #left and right
        if i == 0:
            ch = 'C4'
            taskLabel = 'task_left'
        else:
            ch = 'C3'
            taskLabel = 'task_right'
        block_psd = calc_block_psd(task[i], taskLabel, ch)
        for bNum, block in enumerate(['b1', 'b2', 'b3', 'b4', 'b5']):
            dfList[i] = dfList[i].append(pd.Series([block, 100*(block_psd[bNum]-baseline[i])/baseline[i]], index=dfList[i].columns), ignore_index=True)

# %%
raw = mne.io.read_raw_brainvision('result/sha1_Day1.vhdr', preload=True)
#filter
raw.notch_filter(freqs=60)
raw.filter(l_freq=3, h_freq=50)
#re-refernce
re_signal = raw.get_data()[raw.ch_names.index('A2')] / 2
new_raw = raw.get_data()
new_raw[raw.ch_names.index('A2')] = re_signal
raw = mne.io.RawArray(new_raw, info=raw.info)
raw.set_eeg_reference(ref_channels=['A2'])
#epoch
events = mne.find_events(raw, stim_channel='TRIGGER')
trigger_table = pd.read_csv('trigger_table.csv')
trigger_table['sendnum'] = trigger_table['trigger'] * 256
event_id = trigger_table.set_index('label')['sendnum'].to_dict()
epochs = mne.Epochs(raw, events, event_id, tmin=-1, tmax=4, detrend=1)
task = [epochs['task_left'], epochs['task_right']]
Mitask = [epochs['Mitest_post_taskleft'], epochs['Mitest_post_taskright']]
Mirelax = [epochs['Mitest_post_relaxleft'], epochs['Mitest_post_relaxright']]
# Out:
# Extracting parameters from result/sha1_Day1.vhdr...
# Setting channel info structure...
# Reading 0 ... 1074373  =      0.000 ...  2148.746 secs...
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 3 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 3.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 2.00 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (1.650 sec)
#
# Creating RawArray with float64 data, n_channels=25, n_times=1074374
#     Range : 0 ... 1074373 =      0.000 ...  2148.746 secs
# Ready.
# Applying a custom EEG reference.
# 334 events found
# Event IDs: [   0  256  768 1280 1792 2048 2304 2560 2816 3072 3328 3584 3840 4352
#  4608 4864 5120 5376 5632 5888 6144 6400]
# <ipython-input-8-6b2332abb1d8>:12: RuntimeWarning: Trigger channel contains negative values, using absolute value. If data were acquired on a Neuromag system with STI016 active, consider using uint_cast=True to work around an acquisition bug
#   events = mne.find_events(raw, stim_channel='TRIGGER')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6b2332abb1d8> in <module>
#      14 trigger_table['sendnum'] = trigger_table['trigger'] * 256
#      15 event_id = trigger_table.set_index('label')['sendnum'].to_dict()
# ---> 16 epochs = mne.Epochs(raw, events, event_id, tmin=-1, tmax=4, detrend=1)
#      17 task = [epochs['task_left'], epochs['task_right']]
#      18 Mitask = [epochs['Mitest_post_taskleft'], epochs['Mitest_post_taskright']]
#
# </usr/local/lib/python3.7/site-packages/mne/externals/decorator.py:decorator-gen-204> in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, verbose)
#
# /usr/local/lib/python3.7/site-packages/mne/utils/_logging.py in wrapper(*args, **kwargs)
#      87             with use_log_level(verbose_level):
#      88                 return function(*args, **kwargs)
# ---> 89         return function(*args, **kwargs)
#      90     return FunctionMaker.create(
#      91         function, 'return decfunc(%(signature)s)',
#
# /usr/local/lib/python3.7/site-packages/mne/epochs.py in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, verbose)
#    1810             reject_tmax=reject_tmax, detrend=detrend,
#    1811             proj=proj, on_missing=on_missing, preload_at_end=preload,
# -> 1812             verbose=verbose)
#    1813
#    1814     @verbose
#
# </usr/local/lib/python3.7/site-packages/mne/externals/decorator.py:decorator-gen-195> in __init__(self, info, data, events, event_id, tmin, tmax, baseline, raw, picks, reject, flat, decim, reject_tmin, reject_tmax, detrend, proj, on_missing, preload_at_end, selection, drop_log, filename, metadata, verbose)
#
# /usr/local/lib/python3.7/site-packages/mne/utils/_logging.py in wrapper(*args, **kwargs)
#      87             with use_log_level(verbose_level):
#      88                 return function(*args, **kwargs)
# ---> 89         return function(*args, **kwargs)
#      90     return FunctionMaker.create(
#      91         function, 'return decfunc(%(signature)s)',
#
# /usr/local/lib/python3.7/site-packages/mne/epochs.py in __init__(***failed resolving arguments***)
#     286                            '(event id %i)' % (key, val))
#     287                     if on_missing == 'error':
# --> 288                         raise ValueError(msg)
#     289                     elif on_missing == 'warning':
#     290                         warn(msg)
#
# ValueError: No matching events found for instruction (event id 1536)

# %%
trigger_table
# Out:
#                      label  trigger  sendnum
# 0                    start        1      256
# 1                 flandars        3      768
# 2                     KVIQ        5     1280
# 3              instruction        6     1536
# 4               Mitest_pre        7     1792
# 5     Mitest_pre_relaxleft        8     2048
# 6      Mitest_pre_taskleft        9     2304
# 7    Mitest_pre_relaxright       10     2560
# 8     Mitest_pre_taskright       11     2816
# 9                 baseline       12     3072
# 10          training_start       13     3328
# 11              relax_left       14     3584
# 12               task_left       15     3840
# 13             relax_right       16     4096
# 14              task_right       17     4352
# 15                    rest       18     4608
# 16         training_finish       19     4864
# 17             Mitest_post       20     5120
# 18   Mitest_post_relaxleft       21     5376
# 19    Mitest_post_taskleft       22     5632
# 20  Mitest_post_relaxright       23     5888
# 21   Mitest_post_taskright       24     6144
# 22                  finish       25     6400
