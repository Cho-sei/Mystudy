# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import itertools
import seaborn as sns
sns.set()

# %%
p_info = pd.read_csv('pre_participants.csv')

# %%
summary = pd.DataFrame()
for pid in p_info['pid']:
    data = pd.read_csv('result/' + pid + '_MItask.csv', index_col=0)
    summary = summary.append(data)

# %%
data = summary.groupby(['condition', 'day', 'timing', 'hand'], sort=None, as_index=False).mean()

# %%
data[(data.condition == 'control') & (data.hand == 'left')]
# Out:
#    condition   day timing  hand  block         RT
# 12   control  Day1    pre  left      2  27.981448
# 14   control  Day1   post  left      2  17.853853
# 16   control  Day2    pre  left      2  14.166414
# 19   control  Day2   post  left      2  14.679478
# 21   control  Day3    pre  left      2  14.486300
# 22   control  Day3   post  left      2  14.441730

# %%
MI_Xaxis = ['Day1_pre', 'Day1_post', 'Day2_pre', 'Day2_post', 'Day3_pre', 'Day3_post']
data = summary.groupby(['condition', 'day', 'timing', 'hand'], sort=None, as_index=False).mean()
plt.figure(figsize=(15, 5))
for i, hand in enumerate(['left', 'right']):
    plt.subplot(1, 2, i+1)
    plt.plot(MI_Xaxis, data[(data.condition == 'control') & (data.hand == hand)]['RT'], label='control')
    plt.plot(MI_Xaxis, data[(data.condition == 'continuous') & (data.hand == hand)]['RT'], label='NFB')
    plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
    plt.title(hand)

# %%
PTsummary = pd.DataFrame()
for pid in p_info['pid']:
    PT_data = pd.read_csv('result/' + pid + '_PT.csv', index_col=0)
    PTsummary = PTsummary.append(PT_data)

# %%
plt.figure(figsize=(10,5))
data = PTsummary.groupby(['pid', 'condition', 'timing', 'hand'], sort=None, as_index=False).mean()
for i, hand in enumerate(['left', 'right']):
    plt.subplot(1, 2, i+1)
    sns.lineplot(x='timing', y='PTime', hue='condition', sort=False, err_style='bars', data=data[data.hand == hand])
    plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
    plt.title('performance time ' + hand)

# %%
PTsummary.groupby(['pid', 'condition', 'timing', 'hand'], sort=None, as_index=False).mean()
# Out:
#       pid   condition timing   hand  trial      PTime
# 0    tani  continuous    pre  right      0  18.155197
# 1    tani  continuous    pre   left      0  14.263131
# 2    tani  continuous   post  right      1   9.547842
# 3    tani  continuous   post   left      1  10.225714
# 4      Yu  continuous    pre  right      1   8.229601
# 5      Yu  continuous    pre   left      1   9.067651
# 6      Yu  continuous   post  right      1   8.419161
# 7      Yu  continuous   post   left      1   8.611024
# 8   Okubo     control    pre  right      1  15.769507
# 9   Okubo     control    pre   left      1  13.511567
# 10  Okubo     control   post  right      1  11.882109
# 11  Okubo     control   post   left      1  12.080211

# %%
MC_df = summary[(summary.day == 'Day1') & (summary.timing == 'pre') & (summary.hand == 'left')].groupby(['pid', 'condition', 'day', 'timing', 'hand'], sort=None, as_index=False).mean()
MC_df['PT'] = PTsummary[(PTsummary.timing == 'pre') & (PTsummary.hand == 'left')].groupby(['pid', 'condition', 'timing', 'hand'], sort=None, as_index=False).mean()['PTime']

# %%
MC_df['PT'] = PTsummary[(PTsummary.timing == 'pre') & (PTsummary.hand == 'left')].groupby(['pid', 'condition', 'timing', 'hand'], sort=None, as_index=False).mean()['PTime']

# %%
MC_df
# Out:
#      pid   condition   day timing  hand  block         RT         PT
# 0   tani  continuous  Day1    pre  left      2  25.291252  14.263131
# 1     Yu  continuous  Day1    pre  left      2  24.625120   9.067651
# 2  Okubo     control  Day1    pre  left      2  27.981448  13.511567

# %%
MC_df.reset_index()
# Out:
#    index    pid condition   day timing   hand  Unnamed: 0  block         RT  \
# 0      0  Okubo   control  Day1    pre  right         4.6    2.0  31.544696
# 1      1  Okubo   control  Day1    pre   left         5.5    2.5  28.371923
# 2     10  Okubo   control  Day3   post   left         4.2    2.0  14.441730
# 3     11  Okubo   control  Day3   post  right         4.8    2.0  14.370106
#
#           PT
# 0  15.769507
# 1  13.511567
# 2  11.882109
# 3  12.080211

# %%
for i, hand in enumerate(['left', 'right']):
    plt.subplot(1, 2, i+1)
    plt.bar(['pre', 'post'], abs(MC_df[MC_df.hand == hand].RT - MC_df[MC_df.hand == hand].PT), width=0.5)
    plt.title('MC_' + hand)

# %%
origin_data
# Out:
#     Unnamed: 0    pid condition   day timing  block   hand         RT
# 1            1  Okubo   control  Day1    pre      0  right  33.245253
# 2            2  Okubo   control  Day1    pre      1  right  29.860504
# 3            3  Okubo   control  Day1    pre      1   left  27.827515
# 4            4  Okubo   control  Day1    pre      2  right  37.881633
# 5            5  Okubo   control  Day1    pre      2   left  32.586068
# 6            6  Okubo   control  Day1    pre      3   left  27.803195
# 7            7  Okubo   control  Day1    pre      3  right  29.835444
# 8            8  Okubo   control  Day1    pre      4   left  25.270914
# 9            9  Okubo   control  Day1    pre      4  right  26.900648
# 10           0  Okubo   control  Day1   post      0   left  20.208786
# 11           1  Okubo   control  Day1   post      0  right  17.482689
# 12           2  Okubo   control  Day1   post      1  right  14.754915
# 13           3  Okubo   control  Day1   post      1   left  16.094473
# 14           4  Okubo   control  Day1   post      2  right  14.395031
# 15           5  Okubo   control  Day1   post      2   left  18.032821
# 16           6  Okubo   control  Day1   post      3  right  15.190194
# 17           7  Okubo   control  Day1   post      3   left  16.427072
# 18           8  Okubo   control  Day1   post      4  right  14.819607
# 19           9  Okubo   control  Day1   post      4   left  18.506115
# 20           0  Okubo   control  Day2    pre      0   left  15.172619
# 21           1  Okubo   control  Day2    pre      0  right  14.355422
# 22           2  Okubo   control  Day2    pre      1  right  14.001188
# 23           3  Okubo   control  Day2    pre      1   left  13.809849
# 24           4  Okubo   control  Day2    pre      2   left  15.156397
# 25           5  Okubo   control  Day2    pre      2  right  13.888813
# 26           6  Okubo   control  Day2    pre      3   left  13.291463
# 27           7  Okubo   control  Day2    pre      3  right  14.188243
# 28           8  Okubo   control  Day2    pre      4   left  13.401741
# 29           9  Okubo   control  Day2    pre      4  right  13.320485
# 30           0  Okubo   control  Day2   post      0  right  15.848111
# 31           1  Okubo   control  Day2   post      0   left  15.920926
# 32           2  Okubo   control  Day2   post      1   left  14.527409
# 33           3  Okubo   control  Day2   post      1  right  14.294867
# 34           4  Okubo   control  Day2   post      2   left  13.143967
# 35           5  Okubo   control  Day2   post      2  right  12.992413
# 36           6  Okubo   control  Day2   post      3  right  14.471599
# 37           7  Okubo   control  Day2   post      3   left  14.280915
# 38           8  Okubo   control  Day2   post      4  right  14.658068
# 39           9  Okubo   control  Day2   post      4   left  15.524174
# 40           0  Okubo   control  Day3    pre      0  right  14.216823
# 41           1  Okubo   control  Day3    pre      0   left  14.788419
# 42           2  Okubo   control  Day3    pre      1   left  16.598132
# 43           3  Okubo   control  Day3    pre      1  right  15.067396
# 44           4  Okubo   control  Day3    pre      2  right  14.877207
# 45           5  Okubo   control  Day3    pre      2   left  13.850998
# 46           6  Okubo   control  Day3    pre      3   left  13.410051
# 47           7  Okubo   control  Day3    pre      3  right  14.549697
# 48           8  Okubo   control  Day3    pre      4   left  13.783898
# 49           9  Okubo   control  Day3    pre      4  right  16.976626
# 50           0  Okubo   control  Day3   post      0   left  13.784035
# 51           1  Okubo   control  Day3   post      0  right  13.509928
# 52           2  Okubo   control  Day3   post      1  right  15.103892
# 53           3  Okubo   control  Day3   post      1   left  16.935286
# 54           4  Okubo   control  Day3   post      2   left  12.747861
# 55           5  Okubo   control  Day3   post      2  right  11.852035
# 56           6  Okubo   control  Day3   post      3   left  12.385324
# 57           7  Okubo   control  Day3   post      3  right  15.008666
# 58           8  Okubo   control  Day3   post      4   left  16.356141
# 59           9  Okubo   control  Day3   post      4  right  16.376009
